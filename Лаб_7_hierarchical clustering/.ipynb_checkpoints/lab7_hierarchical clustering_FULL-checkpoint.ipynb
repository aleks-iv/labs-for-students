# %% [markdown]
# ## Hierarchical clustering

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.io import loadmat
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering, KMeans
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
def plot_dendrogram(model, X):
    linkage_matrix = linkage(X, model.linkage)

    plt.figure(figsize=(10, 5))
    dendrogram(linkage_matrix, color_threshold=0)

# %% [markdown]
# ### Hierarchical clustering on example dataset

# %%
data = loadmat('data.mat')
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X'])

# %%
X = data['X']
print('X:', X.shape)
# Out:
# X: (300, 2)

# %%
model = AgglomerativeClustering(n_clusters=k_clusters, affinity='euclidean', linkage='complete')
model.fit(X)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='complete', memory=None, n_clusters=3,
#                         pooling_func='deprecated')

# %%
plot_dendrogram(model, X)

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.scatter(X[:,0], X[:,1])
plt.title('Original data')

plt.subplot(1, 2, 2)
plt.scatter(X[:,0], X[:,1], s=40, c=model.labels_, cmap=plt.cm.prism) 
plt.title('Hierarchical clustering results')
# Out:
# Text(0.5, 1.0, 'Hierarchical clustering results')

# %% [markdown]
# ### Image compression with hierarchical clustering

# %%
original_image = plt.imread('bird_small.png')
img_h = original_image.shape[0]
img_w = original_image.shape[1]

# %%
img = original_image/255
img = img.reshape(img_h*img_w, 3)
img.shape
# Out:
# (16384, 3)

# %%
k_colors = 16
model = AgglomerativeClustering(n_clusters=k_colors)
model.fit(img)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='ward', memory=None, n_clusters=16,
#                         pooling_func='deprecated')

# %%
centers = np.zeros((self.number_of_clusters, 3))
        for i in range(0, self.number_of_clusters):
            cluster_points = image_cols[ward.labels_ == i]
            cluster_mean = np.mean(cluster_points, axis=0)
            centers[i, :] = cluster_meancluster_centers = np.zeros((16, 3))
# Out:
# (16, 3)

# %%
compressed_image = model.cluster_centers_[model.labels_].reshape(img_shape[0], img_shape[1], 3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-233-1e3505555d36> in <module>
# ----> 1 compressed_image = model.cluster_centers_[model.labels_].reshape(img_shape[0], img_shape[1], 3)
#
# AttributeError: 'AgglomerativeClustering' object has no attribute 'cluster_centers_'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-244-d645c9a52bf4> in <module>
# ----> 1 mean(model.labels_)
#
# NameError: name 'mean' is not defined

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,9))
ax1.imshow(original_image)
ax1.set_title('Original')
ax2.imshow(compressed_image*255)
ax2.set_title(f'Compressed, with {k_colors} colors')

for ax in fig.axes:
    ax.axis('off')

# %%
m = KMeans(n_clusters=16)
m.fit(img)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=16, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
m.cluster_centers_.shape
# Out:
# (16, 3)

# %%
m.labels_
# Out:
# array([2, 2, 2, ..., 1, 1, 1])

# %%
# Out:
# 8
